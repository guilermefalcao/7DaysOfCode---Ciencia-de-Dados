# %% [markdown]
# # Dia 1 - Exploração dos Dados CEAPS
#
# Vamos explorar os dados de despesas dos senadores!

# %% [markdown]
# ## 1. Importar Bibliotecas

# %%
import pandas as pd
import numpy as np

print("✅ Bibliotecas importadas com sucesso!")
# Out:
# ✅ Bibliotecas importadas com sucesso!

# %% [markdown]
# ## 2. Carregar Dados de 2022

# %%
# Carregar arquivo CSV
df = pd.read_csv('../Dados Abertos - CEAPS - csv/despesa_ceaps_2022.csv', 
                 encoding='latin-1', 
                 sep=';')

print(f"📊 Dados carregados: {df.shape[0]} linhas e {df.shape[1]} colunas")
print("\n🔍 Primeiras 5 linhas:")
df.head()
# Out:
# 📊 Dados carregados: 16806 linhas e 2 colunas
#
# 🔍 Primeiras 5 linhas:
#                                                                                                                                                                                                               ULTIMA ATUALIZACAO  \
# ANO  MES SENADOR      TIPO_DESPESA                                       CNPJ_CPF           FORNECEDOR                        DOCUMENTO         DATA       DETALHAMENTO                                        VALOR_REEMBOLSADO
# 2022 1   ACIR GURGACZ Aluguel de imóveis para escritório político, co... 004.948.028-63     GILBERTO PISELO DO NASCIMENTO     001/22            03/01/2022 Despesa com pagamento de aluguel de imóvel para...               6000
#                       Divulgação da atividade parlamentar                26.320.603/0001-64 INFORMANAHORA                     000000000000310/A 04/01/2022 Despesa com divulgação da atividade parlamentar...               1500
# ...

# %% [markdown]
# ## 3. Ver Nomes das Colunas

# %%
print("📋 Colunas disponíveis:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# 📋 Colunas disponíveis:
# 1. ULTIMA ATUALIZACAO
# 2. 02/02/2026 02:01

# %% [markdown]
# ## 4. Informações Gerais

# %%
print("ℹ️ Informações do Dataset:")
df.info()
# Out:
# ℹ️ Informações do Dataset:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 16806 entries, ('ANO', 'MES', 'SENADOR', 'TIPO_DESPESA', 'CNPJ_CPF', 'FORNECEDOR', 'DOCUMENTO', 'DATA', 'DETALHAMENTO') to ('2022', '12', 'ZEQUINHA MARINHO', 'Passagens aéreas, aquáticas e terrestres nacionais', '22.052.777/0001-32', 'Exceller Tour', 'WMQWBX', '30/12/2022', 'Companhia Aérea: TAM, Localizador: WMQWBX. Passageiros: YURI PEREIRA CARNEIRO AGE (Matrícula 300461, COMISSIONADO), Voo: 3608 - BSB/BELÉM - 08/01/2023; YURI PEREIRA CARNEIRO AGE (Matrícula 300461, COMISSIONADO), Voo: 3609 - BELÉM/BSB - 20/01/2023;')
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ULTIMA ATUALIZACAO  16806 non-null  object
#  1   02/02/2026 02:01    16806 non-null  object
# dtypes: object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 5. Verificar Valores Nulos

# %%
print("❌ Valores nulos por coluna:")
nulos = df.isnull().sum()
print(nulos[nulos > 0])

print(f"\n📊 Total de valores nulos: {df.isnull().sum().sum()}")
# Out:
# ❌ Valores nulos por coluna:
# Series([], dtype: int64)
#
# 📊 Total de valores nulos: 0

# %% [markdown]
# ## 6. Estatísticas dos Senadores

# %%
print("👥 Quantos senadores diferentes?")
print(f"Total: {df['SENADOR'].nunique()} senadores")

print("\n🔝 Top 5 senadores com mais despesas:")
top_senadores = df['SENADOR'].value_counts().head()
print(top_senadores)
# Out:
# 👥 Quantos senadores diferentes?
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\guilherme.falcao\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SENADOR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
# ...

# %%
print("👥 Quantos senadores diferentes?")
print(f"Total: {df['SENADOR'].nunique()} senadores")

print("\n🔝 Top 5 senadores com mais despesas:")
top_senadores = df['SENADOR'].value_counts().head()
print(top_senadores)
# Out:
# 👥 Quantos senadores diferentes?
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# File c:\Users\guilherme.falcao\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#
#    3804 try:
#
# -> 3805     return self._engine.get_loc(casted_key)
#
#    3806 except KeyError as err:
#
#
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# KeyError: 'SENADOR'
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# ...

# %% [markdown]
# ## 7. Tipos de Despesas

# %%
print("💰 Tipos de despesas mais comuns:")
tipos = df['TIPO_DESPESA'].value_counts()
print(tipos)
# Out:
# 💰 Tipos de despesas mais comuns:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\guilherme.falcao\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TIPO_DESPESA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
# ...

# %% [markdown]
# ## 8. Análise de Valores

# %%
# Converter valores para numérico
df['VALOR_NUM'] = df['VALOR_REEMBOLSADO'].str.replace(',', '.').astype(float)

print("💵 Estatísticas dos valores:")
print(f"Valor mínimo: R$ {df['VALOR_NUM'].min():.2f}")
print(f"Valor máximo: R$ {df['VALOR_NUM'].max():.2f}")
print(f"Valor médio: R$ {df['VALOR_NUM'].mean():.2f}")
print(f"Valor total: R$ {df['VALOR_NUM'].sum():,.2f}")

# %% [markdown]
# ## 9. Despesas por Mês

# %%
print("📅 Despesas por mês em 2022:")
despesas_mes = df.groupby('MES')['VALOR_NUM'].sum().sort_index()
print(despesas_mes)

# %% [markdown]
# ## 10. Resumo Final

# %%
print("="*50)
print("📊 RESUMO DOS DADOS - 2022")
print("="*50)
print(f"Total de registros: {len(df):,}")
print(f"Total de senadores: {df['SENADOR'].nunique()}")
print(f"Total de fornecedores: {df['FORNECEDOR'].nunique()}")
print(f"Valor total gasto: R$ {df['VALOR_NUM'].sum():,.2f}")
print(f"Média por despesa: R$ {df['VALOR_NUM'].mean():.2f}")
print("="*50)
